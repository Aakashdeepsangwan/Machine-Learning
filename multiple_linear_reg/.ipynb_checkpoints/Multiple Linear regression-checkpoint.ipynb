# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('economic_index.csv')

# %%
df.head()
# Out:
#    interest_rate  unemployment_rate  index_price
# 0           2.75                5.3         1464
# 1           2.50                5.3         1394
# 2           2.50                5.3         1357
# 3           2.50                5.3         1293
# 4           2.50                5.4         1256

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   interest_rate      24 non-null     float64
#  1   unemployment_rate  24 non-null     float64
#  2   index_price        24 non-null     int64
# dtypes: float64(2), int64(1)
# memory usage: 708.0 bytes

# %%
df.drop(columns = ['Unnamed: 0','year','month'],axis=1,inplace = True)

# %%
df.head()
# Out:
#    interest_rate  unemployment_rate  index_price
# 0           2.75                5.3         1464
# 1           2.50                5.3         1394
# 2           2.50                5.3         1357
# 3           2.50                5.3         1293
# 4           2.50                5.4         1256

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                    interest_rate  unemployment_rate  index_price
# interest_rate           1.000000          -0.925814     0.935793
# unemployment_rate      -0.925814           1.000000    -0.922338
# index_price             0.935793          -0.922338     1.000000

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
y
# Out:
# 0     1464
# 1     1394
# 2     1357
# 3     1293
# 4     1256
# 5     1254
# 6     1234
# 7     1195
# 8     1159
# 9     1167
# 10    1130
# 11    1075
# 12    1047
# 13     965
# 14     943
# 15     958
# 16     971
# 17     949
# 18     884
# 19     866
# 20     876
# 21     822
# 22     704
# 23     719
# Name: index_price, dtype: int64

# %%
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.25, random_state = 42)

# %%
y_test
# Out:
# 8     1159
# 16     971
# 0     1464
# 18     884
# 11    1075
# 9     1167
# Name: index_price, dtype: int64

# %% [markdown]
# ## Plot regression line using Seaborn

# %%
sns.regplot(x=df['interest_rate'],y=df['index_price'])
# Out:
# <Axes: xlabel='interest_rate', ylabel='index_price'>

# %%
sns.regplot(x = df['unemployment_rate'],y = df['interest_rate'])
# Out:
# <Axes: xlabel='unemployment_rate', ylabel='interest_rate'>

# %%
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
X_train
# Out:
# array([[-0.90115511,  0.37908503],
#        [ 1.31077107, -1.48187786],
#        [-0.90115511,  1.30956648],
#        [ 1.31077107, -0.55139641],
#        [ 1.31077107, -1.48187786],
#        [-0.16384638,  0.68924552],
#        [-0.90115511,  0.999406  ],
#        [ 1.31077107, -1.48187786],
#        [ 1.31077107, -1.17171738],
#        [-0.90115511,  1.30956648],
#        [-0.90115511,  0.999406  ],
#        [-0.90115511,  0.37908503],
#        [-0.90115511,  0.999406  ],
#        [ 0.57346234, -0.8615569 ],
#        [-0.16384638, -0.24123593],
#        [-0.90115511,  0.06892455],
#        [-0.90115511,  0.999406  ],
#        [ 1.31077107, -0.8615569 ]])

# %%
from sklearn.linear_model import LinearRegression 
regression = LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import cross_val_score 
validation_score = cross_val_score(regression, X_train,y_train, scoring = 'neg_mean_squared_error',
                                   cv = 3)

# %%
np.mean(validation_score) # We use this number to check and compare bwt model, to see whether the model is good enough (smaller MSE = better)
# Out:
# np.float64(-5914.828180162395)

# %% [markdown]
# ## Y_predict

# %%
y_pred = regression.predict(X_test)

# %%
y_pred
# Out:
# array([1180.7466813 ,  802.74279699, 1379.83457045,  838.52599602,
#         973.85313963, 1144.96348227])

# %%
### MSE, MAE, RMSE 
from sklearn.metrics import mean_absolute_error, mean_squared_error
mse = mean_squared_error(y_test, y_pred) 
mae = mean_absolute_error(y_test, y_pred) 
rmse = np.sqrt(mse) 
print(mse)
print(mae)
print(rmse)
# Out:
# 8108.567426306604
# 73.80444932337097
# 90.04758423359621

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, y_pred) 
print(score) 
r_adjusted = 1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
print(r_adjusted)
# Out:
# 0.7591371539010257
# 0.5985619231683761

# %% [markdown]
# ## Assumptions

# %%
plt.scatter(y_test,y_pred)

# %%
y_test
# Out:
# 8     1159
# 16     971
# 0     1464
# 18     884
# 11    1075
# 9     1167
# Name: index_price, dtype: int64

# %%
y_pred
# Out:
# array([1180.7466813 ,  802.74279699, 1379.83457045,  838.52599602,
#         973.85313963, 1144.96348227])

# %%
residuals = y_test - y_pred 
print(residuals)
# Out:
# 8     -21.746681
# 16    168.257203
# 0      84.165430
# 18     45.474004
# 11    101.146860
# 9      22.036518
# Name: index_price, dtype: float64

# %%
sns.displot(residuals,kind = 'kde')

# %% [markdown]
# The model you created is good since residuals is uniformly distributed

# %%
plt.scatter(y_pred, residuals)

# %% [markdown]
# Does not follow any trend => residuals uniformly distributed

# %% [markdown]
# ## OLS REGRESSION

# %%
import statsmodels.api as sm

# %%
model = sm.OLS(y_train, X_train).fit()

# %%
model.summary()
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=18 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:            index_price   R-squared (uncentered):                   0.035
# Model:                            OLS   Adj. R-squared (uncentered):             -0.086
# Method:                 Least Squares   F-statistic:                             0.2880
# Date:                Mon, 15 Jun 2026   Prob (F-statistic):                       0.754
# Time:                        01:07:06   Log-Likelihood:                         -150.85
# No. Observations:                  18   AIC:                                      305.7
# Df Residuals:                      16   BIC:                                      307.5
# ...

# %%
print(regression.coef_)
# Out:
# [  88.27275507 -116.25716066]

# %% [markdown]
# ## In Conclusion

# %% [markdown]
# The result is not statistically significant. If I collected a new dataset, I would not get roughly the same coefficient again.
